# %%
import tensorflow as tf
import pprint
import numpy as np

# Log in to your W&B account
# !pip install wandb
import wandb
wandb.login()
# API: 18fe909a998e642a33986bd03c61ee2c6922f72d


# Loading the MNIST dataset in one line
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

x_train_normalized = x_train/255
x_test_normalized = x_test/255
x_train= x_train_normalized.reshape(-1, 28, 28, 1)
x_test = x_test_normalized.reshape(-1, 28, 28, 1)

# Printing the shape
print('x_train:', x_train.shape)
print('y_train:', y_train.shape)
print('x_test:', x_test.shape)
print('y_test:', y_test.shape)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Requirement already satisfied: wandb in /opt/conda/lib/python3.10/site-packages (0.15.9)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /opt/conda/lib/python3.10/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.1.31)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (5.9.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (1.30.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: PyYAML in /opt/conda/lib/python3.10/site-packages (from wandb) (6.0)
# Requirement already satisfied: pathtools in /opt/conda/lib/python3.10/site-packages (from wandb) (0.1.2)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.10/site-packages (from wandb) (1.3.2)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from wandb) (68.0.0)
# Requirement already satisfied: appdirs>=1.4.3 in /opt/conda/lib/python3.10/site-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.20.3)
# Requirement already satisfied: six>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb) (4.0.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2023.7.22)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb) (5.0.0)
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#   ········································
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# x_train: (60000, 28, 28, 1)
# y_train: (60000,)
# x_test: (10000, 28, 28, 1)
# y_test: (10000,)

# %%
def Net(neurons1=26, neurons2=26, neurons3=54, acivation1='relu',activation2='relu',activation3='sigmoid',do1=0.2, do2=0.2, do3=0.2, do4=0.2, gn1=0.1):
    return tf.keras.models.Sequential(
    [
    tf.keras.layers.InputLayer(input_shape=(28,28,1)),
    tf.keras.layers.Conv2D(filters=neurons1, kernel_size=5, padding='same', activation=acivation1),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(do1),
    tf.keras.layers.Conv2D(filters=neurons2, kernel_size=5, padding='same', activation=activation2, kernel_initializer=tf.keras.initializers.HeNormal()), #new
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(do2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(do3),
    tf.keras.layers.Dense(neurons3, kernel_regularizer = tf.keras.regularizers.l2(0.07), activation = activation3),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(do4),
    tf.keras.layers.GaussianNoise(gn1),
    tf.keras.layers.Dense(10, activation='softmax')
    ]
)

model = Net()
model.summary()

def get_optimizer(lr=1e-3, optimizer="adam"):
    "Select optmizer between adam and sgd with momentum"
    if optimizer.lower() == "adam":
        return tf.keras.optimizers.Adam(learning_rate=lr)
    if optimizer.lower() == "sgd":
        return tf.keras.optimizers.SGD(learning_rate=lr, momentum=0.1)

def train(model, batch_size=64, epochs=10, lr=1e-3, optimizer='adam', log_freq='epoch'):

    # Compile model like you usually do.
    tf.keras.backend.clear_session()

    # Compile modell
    loss_fn = tf.keras.losses.SparseCategoricalCrossentropy() #from_logits=True
    sampleID = 100
    loss_fn(y_train[:1], model(x_train[sampleID-1:sampleID]).numpy()).numpy()

    model.compile(loss=loss_fn,
                  optimizer=get_optimizer(lr, optimizer),
                  metrics=['accuracy'])

    # callback setup
    wandb_callbacks = [wandb.keras.WandbCallback(log_freq=log_freq,save_model=(False),) ]

    # Train your model
    model.fit(
        x_train,
        y_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_data = (x_test, y_test),
        callbacks = [wandb_callbacks]
        )

# Configure Sweep
sweep_config = {
    'method': 'bayes',
    'metric': {
        'goal': 'maximize',
        'name': 'val_accuracy'
    },
    'early_terminate': {
        "type": "hyperband",
        "eta": 2,
        "min_iter":3
     }
}
parameters_dict = {
    'optimizer': {
        'value': 'adam'
        },
    'epochs': {
        'value': 20
        },
    'batch_size' : {
        'value': 32
        },
    'learning_rate': {
        'value': 1e-5
    },
     'neurons1': {
        'value': 26
    },
    'neurons2': {
        'value': 26
    },
    'neurons3': {
        'value': 54
    },

    'activation1' : {
        'value' :  ['relu']
    },
    'activation2' : {
        'value' : ['relu']
    },
    'activation3' : {
        'value' : ['sigmoid']
    },
    'do1' : {
        'values' : list(np.arange(0.01,0.8,0.05))
    },
    'do2' : {
        'values' : list(np.arange(0.01,0.8,0.05))
    },
    'do3' : {
        'values' : list(np.arange(0.01,0.8,0.05))
    },
    'do4' : {
        'values' : list(np.arange(0.01,0.8,0.05))
    },
    'gn1' : {
        'values' : list(np.arange(0.01,0.8,0.05))
    }
}
sweep_config['parameters'] = parameters_dict
pprint.pprint(sweep_config)

def sweep_train(config_defaults=None):
    # Initialize wandb with a sample project name
    with wandb.init(config=config_defaults):  # this gets over-written in the Sweep

        # Specify the other hyperparameters to the configuration, if any
        wandb.config.architecture_name = "V03"
        wandb.config.dataset_name = "MNIST"

        # initialize model
        model = Net(wandb.config.neurons1, wandb.config.neurons2, wandb.config.neurons3)

        train(model,
              wandb.config.batch_size,
              wandb.config.epochs,
              wandb.config.learning_rate,
              wandb.config.optimizer)

sweep_id = wandb.sweep(sweep_config, project="V03_Dropout")
wandb.agent(sweep_id, function=sweep_train, count=30)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 26)        676
#
#  batch_normalization (BatchN  (None, 28, 28, 26)       104
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 26)       0
#  )
#
#  dropout (Dropout)           (None, 14, 14, 26)        0
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 26)        16926
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 26)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 7, 7, 26)          0
#
#  flatten (Flatten)           (None, 1274)              0
#
#  dropout_2 (Dropout)         (None, 1274)              0
#
#  dense (Dense)               (None, 54)                68850
#
#  batch_normalization_1 (Batc  (None, 54)               216
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 54)                0
#
#  gaussian_noise (GaussianNoi  (None, 54)               0
#  se)
#
#  dense_1 (Dense)             (None, 10)                550
#
# =================================================================
# Total params: 87,322
# Trainable params: 87,162
# Non-trainable params: 160
# _________________________________________________________________
# {'early_terminate': {'eta': 2, 'min_iter': 3, 'type': 'hyperband'},
#  'method': 'bayes',
#  'metric': {'goal': 'maximize', 'name': 'val_accuracy'},
#  'parameters': {'activation1': {'value': ['relu']},
#                 'activation2': {'value': ['relu']},
#                 'activation3': {'value': ['sigmoid']},
#                 'batch_size': {'value': 32},
#                 'do1': {'values': [0.01,
#                                    0.060000000000000005,
#                                    0.11,
#                                    0.16000000000000003,
#                                    0.21000000000000002,
#                                    0.26,
#                                    0.31000000000000005,
#                                    0.36000000000000004,
#                                    0.41000000000000003,
#                                    0.46,
#                                    0.51,
#                                    0.56,
#                                    0.6100000000000001,
#                                    0.66,
#                                    0.7100000000000001,
#                                    0.76]},
#                 'do2': {'values': [0.01,
#                                    0.060000000000000005,
#                                    0.11,
#                                    0.16000000000000003,
#                                    0.21000000000000002,
#                                    0.26,
#                                    0.31000000000000005,
#                                    0.36000000000000004,
#                                    0.41000000000000003,
#                                    0.46,
#                                    0.51,
#                                    0.56,
#                                    0.6100000000000001,
#                                    0.66,
#                                    0.7100000000000001,
#                                    0.76]},
#                 'do3': {'values': [0.01,
#                                    0.060000000000000005,
#                                    0.11,
#                                    0.16000000000000003,
#                                    0.21000000000000002,
#                                    0.26,
#                                    0.31000000000000005,
#                                    0.36000000000000004,
#                                    0.41000000000000003,
#                                    0.46,
#                                    0.51,
#                                    0.56,
#                                    0.6100000000000001,
#                                    0.66,
#                                    0.7100000000000001,
#                                    0.76]},
#                 'do4': {'values': [0.01,
#                                    0.060000000000000005,
#                                    0.11,
#                                    0.16000000000000003,
#                                    0.21000000000000002,
#                                    0.26,
#                                    0.31000000000000005,
#                                    0.36000000000000004,
#                                    0.41000000000000003,
#                                    0.46,
#                                    0.51,
#                                    0.56,
#                                    0.6100000000000001,
#                                    0.66,
#                                    0.7100000000000001,
#                                    0.76]},
#                 'epochs': {'value': 20},
#                 'gn1': {'values': [0.01,
#                                    0.060000000000000005,
#                                    0.11,
#                                    0.16000000000000003,
#                                    0.21000000000000002,
#                                    0.26,
#                                    0.31000000000000005,
#                                    0.36000000000000004,
#                                    0.41000000000000003,
#                                    0.46,
#                                    0.51,
#                                    0.56,
#                                    0.6100000000000001,
#                                    0.66,
#                                    0.7100000000000001,
#                                    0.76]},
#                 'learning_rate': {'value': 1e-05},
#                 'neurons1': {'value': 26},
#                 'neurons2': {'value': 26},
#                 'neurons3': {'value': 54},
#                 'optimizer': {'value': 'adam'}}}
# Create sweep with ID: vq8376ic
# Sweep URL: https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic
# wandb: Agent Starting Run: 04idbua1 with config:
# wandb: 	activation1: ['relu']
# wandb: 	activation2: ['relu']
# wandb: 	activation3: ['sigmoid']
# wandb: 	batch_size: 32
# wandb: 	do1: 0.41
# wandb: 	do2: 0.6100000000000001
# wandb: 	do3: 0.7100000000000001
# wandb: 	do4: 0.7100000000000001
# wandb: 	epochs: 20
# wandb: 	gn1: 0.16000000000000003
# wandb: 	learning_rate: 1e-05
# wandb: 	neurons1: 26
# wandb: 	neurons2: 26
# wandb: 	neurons3: 54
# wandb: 	optimizer: adam
# wandb: Currently logged in as: lucas-halt (luchalt). Use `wandb login --relogin` to force relogin
# wandb version 0.15.12 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20231106_152131-04idbua1</code>
# Syncing run <strong><a href='https://wandb.ai/luchalt/V03_Dropout/runs/04idbua1' target="_blank">feasible-sweep-1</a></strong> to <a href='https://wandb.ai/luchalt/V03_Dropout' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic' target="_blank">https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic</a>
#  View project at <a href='https://wandb.ai/luchalt/V03_Dropout' target="_blank">https://wandb.ai/luchalt/V03_Dropout</a>
#  View sweep at <a href='https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic' target="_blank">https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic</a>
#  View run at <a href='https://wandb.ai/luchalt/V03_Dropout/runs/04idbua1' target="_blank">https://wandb.ai/luchalt/V03_Dropout/runs/04idbua1</a>
# Epoch 1/20
# 2023-11-06 15:22:31.617065: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 1875/1875 [==============================] - 13s 5ms/step - loss: 8.3460 - accuracy: 0.3794 - val_loss: 6.3485 - val_accuracy: 0.8241
# Epoch 2/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 5.9181 - accuracy: 0.6872 - val_loss: 4.6512 - val_accuracy: 0.9038
# Epoch 3/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 4.2983 - accuracy: 0.8033 - val_loss: 3.3632 - val_accuracy: 0.9337
# Epoch 4/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 3.0896 - accuracy: 0.8634 - val_loss: 2.3988 - val_accuracy: 0.9492
# Epoch 5/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 2.2188 - accuracy: 0.8934 - val_loss: 1.7142 - val_accuracy: 0.9553
# Epoch 6/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 1.6105 - accuracy: 0.9141 - val_loss: 1.2423 - val_accuracy: 0.9631
# Epoch 7/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 1.1962 - accuracy: 0.9258 - val_loss: 0.9188 - val_accuracy: 0.9663
# Epoch 8/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.9077 - accuracy: 0.9366 - val_loss: 0.6946 - val_accuracy: 0.9700
# Epoch 9/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.7115 - accuracy: 0.9435 - val_loss: 0.5379 - val_accuracy: 0.9735
# Epoch 10/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5692 - accuracy: 0.9505 - val_loss: 0.4275 - val_accuracy: 0.9755
# Epoch 11/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4698 - accuracy: 0.9531 - val_loss: 0.3472 - val_accuracy: 0.9775
# Epoch 12/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3939 - accuracy: 0.9566 - val_loss: 0.2871 - val_accuracy: 0.9798
# Epoch 13/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3365 - accuracy: 0.9599 - val_loss: 0.2415 - val_accuracy: 0.9814
# Epoch 14/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2931 - accuracy: 0.9615 - val_loss: 0.2077 - val_accuracy: 0.9817
# Epoch 15/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2586 - accuracy: 0.9642 - val_loss: 0.1798 - val_accuracy: 0.9827
# Epoch 16/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2325 - accuracy: 0.9662 - val_loss: 0.1587 - val_accuracy: 0.9832
# Epoch 17/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2077 - accuracy: 0.9678 - val_loss: 0.1418 - val_accuracy: 0.9833
# Epoch 18/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1917 - accuracy: 0.9685 - val_loss: 0.1270 - val_accuracy: 0.9846
# Epoch 19/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1770 - accuracy: 0.9696 - val_loss: 0.1152 - val_accuracy: 0.9853
# Epoch 20/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1642 - accuracy: 0.9711 - val_loss: 0.1059 - val_accuracy: 0.9856
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▅▆▇▇▇▇█████████████</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▆▅▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▆▆▇▇▇▇▇███████████</td></tr><tr><td>val_loss</td><td>█▆▅▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.97108</td></tr><tr><td>best_epoch</td><td>19</td></tr><tr><td>best_val_loss</td><td>0.10591</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>loss</td><td>0.16418</td></tr><tr><td>val_accuracy</td><td>0.9856</td></tr><tr><td>val_loss</td><td>0.10591</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">feasible-sweep-1</strong> at: <a href='https://wandb.ai/luchalt/V03_Dropout/runs/04idbua1' target="_blank">https://wandb.ai/luchalt/V03_Dropout/runs/04idbua1</a><br/>Synced 6 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231106_152131-04idbua1/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: icxz75rx with config:
# wandb: 	activation1: ['relu']
# wandb: 	activation2: ['relu']
# wandb: 	activation3: ['sigmoid']
# wandb: 	batch_size: 32
# wandb: 	do1: 0.16000000000000003
# wandb: 	do2: 0.26
# wandb: 	do3: 0.21
# wandb: 	do4: 0.01
# wandb: 	epochs: 20
# wandb: 	gn1: 0.76
# wandb: 	learning_rate: 1e-05
# wandb: 	neurons1: 26
# wandb: 	neurons2: 26
# wandb: 	neurons3: 54
# wandb: 	optimizer: adam
# wandb version 0.15.12 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20231106_152535-icxz75rx</code>
# Syncing run <strong><a href='https://wandb.ai/luchalt/V03_Dropout/runs/icxz75rx' target="_blank">valiant-sweep-2</a></strong> to <a href='https://wandb.ai/luchalt/V03_Dropout' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic' target="_blank">https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic</a>
#  View project at <a href='https://wandb.ai/luchalt/V03_Dropout' target="_blank">https://wandb.ai/luchalt/V03_Dropout</a>
#  View sweep at <a href='https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic' target="_blank">https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic</a>
#  View run at <a href='https://wandb.ai/luchalt/V03_Dropout/runs/icxz75rx' target="_blank">https://wandb.ai/luchalt/V03_Dropout/runs/icxz75rx</a>
# Epoch 1/20
# 2023-11-06 15:26:31.253073: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 1875/1875 [==============================] - 11s 4ms/step - loss: 8.4679 - accuracy: 0.3538 - val_loss: 6.4269 - val_accuracy: 0.8082
# Epoch 2/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 6.0548 - accuracy: 0.6547 - val_loss: 4.7399 - val_accuracy: 0.8924
# Epoch 3/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 4.4344 - accuracy: 0.7787 - val_loss: 3.4647 - val_accuracy: 0.9234
# Epoch 4/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 3.2222 - accuracy: 0.8454 - val_loss: 2.5052 - val_accuracy: 0.9411
# Epoch 5/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 2.3329 - accuracy: 0.8838 - val_loss: 1.8062 - val_accuracy: 0.9517
# Epoch 6/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 1.7072 - accuracy: 0.9063 - val_loss: 1.3145 - val_accuracy: 0.9593
# Epoch 7/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 1.2680 - accuracy: 0.9214 - val_loss: 0.9736 - val_accuracy: 0.9646
# Epoch 8/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.9645 - accuracy: 0.9326 - val_loss: 0.7353 - val_accuracy: 0.9697
# Epoch 9/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.7475 - accuracy: 0.9413 - val_loss: 0.5658 - val_accuracy: 0.9718
# Epoch 10/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5977 - accuracy: 0.9473 - val_loss: 0.4466 - val_accuracy: 0.9740
# Epoch 11/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4862 - accuracy: 0.9512 - val_loss: 0.3598 - val_accuracy: 0.9770
# Epoch 12/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4056 - accuracy: 0.9559 - val_loss: 0.2960 - val_accuracy: 0.9789
# Epoch 13/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3459 - accuracy: 0.9589 - val_loss: 0.2478 - val_accuracy: 0.9810
# Epoch 14/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3004 - accuracy: 0.9612 - val_loss: 0.2123 - val_accuracy: 0.9809
# Epoch 15/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2623 - accuracy: 0.9634 - val_loss: 0.1829 - val_accuracy: 0.9822
# Epoch 16/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2350 - accuracy: 0.9648 - val_loss: 0.1602 - val_accuracy: 0.9837
# Epoch 17/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2104 - accuracy: 0.9681 - val_loss: 0.1422 - val_accuracy: 0.9850
# Epoch 18/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1932 - accuracy: 0.9681 - val_loss: 0.1289 - val_accuracy: 0.9841
# Epoch 19/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1785 - accuracy: 0.9697 - val_loss: 0.1162 - val_accuracy: 0.9860
# Epoch 20/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1667 - accuracy: 0.9697 - val_loss: 0.1061 - val_accuracy: 0.9865
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.004 MB of 0.004 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▄▆▇▇▇▇█████████████</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▆▅▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▆▆▇▇▇▇▇███████████</td></tr><tr><td>val_loss</td><td>█▆▅▄▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.96972</td></tr><tr><td>best_epoch</td><td>19</td></tr><tr><td>best_val_loss</td><td>0.10611</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>loss</td><td>0.16669</td></tr><tr><td>val_accuracy</td><td>0.9865</td></tr><tr><td>val_loss</td><td>0.10611</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">valiant-sweep-2</strong> at: <a href='https://wandb.ai/luchalt/V03_Dropout/runs/icxz75rx' target="_blank">https://wandb.ai/luchalt/V03_Dropout/runs/icxz75rx</a><br/>Synced 6 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231106_152535-icxz75rx/logs</code>
# wandb: Agent Starting Run: nu4z7h3x with config:
# wandb: 	activation1: ['relu']
# wandb: 	activation2: ['relu']
# wandb: 	activation3: ['sigmoid']
# wandb: 	batch_size: 32
# wandb: 	do1: 0.36000000000000004
# wandb: 	do2: 0.16000000000000003
# wandb: 	do3: 0.7100000000000001
# wandb: 	do4: 0.46
# wandb: 	epochs: 20
# wandb: 	gn1: 0.11
# wandb: 	learning_rate: 1e-05
# wandb: 	neurons1: 26
# wandb: 	neurons2: 26
# wandb: 	neurons3: 54
# wandb: 	optimizer: adam
# wandb version 0.15.12 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20231106_152924-nu4z7h3x</code>
# Syncing run <strong><a href='https://wandb.ai/luchalt/V03_Dropout/runs/nu4z7h3x' target="_blank">still-sweep-3</a></strong> to <a href='https://wandb.ai/luchalt/V03_Dropout' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic' target="_blank">https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic</a>
#  View project at <a href='https://wandb.ai/luchalt/V03_Dropout' target="_blank">https://wandb.ai/luchalt/V03_Dropout</a>
#  View sweep at <a href='https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic' target="_blank">https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic</a>
#  View run at <a href='https://wandb.ai/luchalt/V03_Dropout/runs/nu4z7h3x' target="_blank">https://wandb.ai/luchalt/V03_Dropout/runs/nu4z7h3x</a>
# Epoch 1/20
# 2023-11-06 15:30:20.469500: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 1875/1875 [==============================] - 11s 5ms/step - loss: 8.5391 - accuracy: 0.3387 - val_loss: 6.4241 - val_accuracy: 0.8151
# Epoch 2/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 6.0433 - accuracy: 0.6564 - val_loss: 4.7194 - val_accuracy: 0.8917
# Epoch 3/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 4.3971 - accuracy: 0.7818 - val_loss: 3.4268 - val_accuracy: 0.9237
# Epoch 4/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 3.1708 - accuracy: 0.8468 - val_loss: 2.4568 - val_accuracy: 0.9406
# Epoch 5/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 2.2859 - accuracy: 0.8839 - val_loss: 1.7603 - val_accuracy: 0.9508
# Epoch 6/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 1.6636 - accuracy: 0.9064 - val_loss: 1.2733 - val_accuracy: 0.9598
# Epoch 7/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 1.2317 - accuracy: 0.9223 - val_loss: 0.9388 - val_accuracy: 0.9646
# Epoch 8/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.9325 - accuracy: 0.9327 - val_loss: 0.7069 - val_accuracy: 0.9696
# Epoch 9/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.7288 - accuracy: 0.9400 - val_loss: 0.5456 - val_accuracy: 0.9723
# Epoch 10/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5779 - accuracy: 0.9479 - val_loss: 0.4306 - val_accuracy: 0.9754
# Epoch 11/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4737 - accuracy: 0.9515 - val_loss: 0.3467 - val_accuracy: 0.9778
# Epoch 12/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3952 - accuracy: 0.9559 - val_loss: 0.2854 - val_accuracy: 0.9797
# Epoch 13/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3377 - accuracy: 0.9585 - val_loss: 0.2404 - val_accuracy: 0.9815
# Epoch 14/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2918 - accuracy: 0.9614 - val_loss: 0.2055 - val_accuracy: 0.9824
# Epoch 15/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2594 - accuracy: 0.9632 - val_loss: 0.1777 - val_accuracy: 0.9831
# Epoch 16/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2330 - accuracy: 0.9646 - val_loss: 0.1573 - val_accuracy: 0.9839
# Epoch 17/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2093 - accuracy: 0.9673 - val_loss: 0.1396 - val_accuracy: 0.9845
# Epoch 18/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1905 - accuracy: 0.9688 - val_loss: 0.1251 - val_accuracy: 0.9850
# Epoch 19/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1776 - accuracy: 0.9690 - val_loss: 0.1134 - val_accuracy: 0.9861
# Epoch 20/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1670 - accuracy: 0.9704 - val_loss: 0.1049 - val_accuracy: 0.9862
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▅▆▇▇▇▇█████████████</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▆▅▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▅▆▇▇▇▇▇███████████</td></tr><tr><td>val_loss</td><td>█▆▅▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.97042</td></tr><tr><td>best_epoch</td><td>19</td></tr><tr><td>best_val_loss</td><td>0.10488</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>loss</td><td>0.16695</td></tr><tr><td>val_accuracy</td><td>0.9862</td></tr><tr><td>val_loss</td><td>0.10488</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">still-sweep-3</strong> at: <a href='https://wandb.ai/luchalt/V03_Dropout/runs/nu4z7h3x' target="_blank">https://wandb.ai/luchalt/V03_Dropout/runs/nu4z7h3x</a><br/>Synced 6 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231106_152924-nu4z7h3x/logs</code>
# wandb: Agent Starting Run: 4y2x0a09 with config:
# wandb: 	activation1: ['relu']
# wandb: 	activation2: ['relu']
# wandb: 	activation3: ['sigmoid']
# wandb: 	batch_size: 32
# wandb: 	do1: 0.56
# wandb: 	do2: 0.66
# wandb: 	do3: 0.7100000000000001
# wandb: 	do4: 0.060000000000000005
# wandb: 	epochs: 20
# wandb: 	gn1: 0.51
# wandb: 	learning_rate: 1e-05
# wandb: 	neurons1: 26
# wandb: 	neurons2: 26
# wandb: 	neurons3: 54
# wandb: 	optimizer: adam
# wandb version 0.15.12 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20231106_153352-4y2x0a09</code>
# Syncing run <strong><a href='https://wandb.ai/luchalt/V03_Dropout/runs/4y2x0a09' target="_blank">eager-sweep-4</a></strong> to <a href='https://wandb.ai/luchalt/V03_Dropout' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic' target="_blank">https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic</a>
#  View project at <a href='https://wandb.ai/luchalt/V03_Dropout' target="_blank">https://wandb.ai/luchalt/V03_Dropout</a>
#  View sweep at <a href='https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic' target="_blank">https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic</a>
#  View run at <a href='https://wandb.ai/luchalt/V03_Dropout/runs/4y2x0a09' target="_blank">https://wandb.ai/luchalt/V03_Dropout/runs/4y2x0a09</a>
# Epoch 1/20
# 2023-11-06 15:34:49.310579: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 1875/1875 [==============================] - 11s 5ms/step - loss: 8.3990 - accuracy: 0.3605 - val_loss: 6.3611 - val_accuracy: 0.8034
# Epoch 2/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 5.9259 - accuracy: 0.6716 - val_loss: 4.6136 - val_accuracy: 0.8962
# Epoch 3/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 4.2763 - accuracy: 0.7911 - val_loss: 3.3145 - val_accuracy: 0.9276
# Epoch 4/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 3.0663 - accuracy: 0.8513 - val_loss: 2.3603 - val_accuracy: 0.9445
# Epoch 5/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 2.2071 - accuracy: 0.8849 - val_loss: 1.6920 - val_accuracy: 0.9541
# Epoch 6/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 1.6098 - accuracy: 0.9073 - val_loss: 1.2294 - val_accuracy: 0.9607
# Epoch 7/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 1.2037 - accuracy: 0.9203 - val_loss: 0.9143 - val_accuracy: 0.9650
# Epoch 8/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.9201 - accuracy: 0.9319 - val_loss: 0.6961 - val_accuracy: 0.9686
# Epoch 9/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.7236 - accuracy: 0.9397 - val_loss: 0.5412 - val_accuracy: 0.9737
# Epoch 10/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5841 - accuracy: 0.9457 - val_loss: 0.4326 - val_accuracy: 0.9755
# Epoch 11/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4814 - accuracy: 0.9505 - val_loss: 0.3517 - val_accuracy: 0.9780
# Epoch 12/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4037 - accuracy: 0.9547 - val_loss: 0.2927 - val_accuracy: 0.9797
# Epoch 13/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3470 - accuracy: 0.9575 - val_loss: 0.2452 - val_accuracy: 0.9811
# Epoch 14/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3011 - accuracy: 0.9608 - val_loss: 0.2100 - val_accuracy: 0.9823
# Epoch 15/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2657 - accuracy: 0.9633 - val_loss: 0.1834 - val_accuracy: 0.9827
# Epoch 16/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2390 - accuracy: 0.9636 - val_loss: 0.1612 - val_accuracy: 0.9830
# Epoch 17/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2176 - accuracy: 0.9657 - val_loss: 0.1438 - val_accuracy: 0.9844
# Epoch 18/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1985 - accuracy: 0.9674 - val_loss: 0.1295 - val_accuracy: 0.9847
# Epoch 19/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1833 - accuracy: 0.9675 - val_loss: 0.1174 - val_accuracy: 0.9858
# Epoch 20/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1691 - accuracy: 0.9699 - val_loss: 0.1074 - val_accuracy: 0.9863
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▅▆▇▇▇▇█████████████</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▆▄▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▅▆▆▇▇▇▇████████████</td></tr><tr><td>val_loss</td><td>█▆▅▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.96993</td></tr><tr><td>best_epoch</td><td>19</td></tr><tr><td>best_val_loss</td><td>0.10745</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>loss</td><td>0.16906</td></tr><tr><td>val_accuracy</td><td>0.9863</td></tr><tr><td>val_loss</td><td>0.10745</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">eager-sweep-4</strong> at: <a href='https://wandb.ai/luchalt/V03_Dropout/runs/4y2x0a09' target="_blank">https://wandb.ai/luchalt/V03_Dropout/runs/4y2x0a09</a><br/>Synced 6 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231106_153352-4y2x0a09/logs</code>
# wandb: Agent Starting Run: oexlrfcc with config:
# wandb: 	activation1: ['relu']
# wandb: 	activation2: ['relu']
# wandb: 	activation3: ['sigmoid']
# wandb: 	batch_size: 32
# wandb: 	do1: 0.060000000000000005
# wandb: 	do2: 0.51
# wandb: 	do3: 0.46
# wandb: 	do4: 0.16000000000000003
# wandb: 	epochs: 20
# wandb: 	gn1: 0.060000000000000005
# wandb: 	learning_rate: 1e-05
# wandb: 	neurons1: 26
# wandb: 	neurons2: 26
# wandb: 	neurons3: 54
# wandb: 	optimizer: adam
# wandb version 0.15.12 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20231106_153821-oexlrfcc</code>
# Syncing run <strong><a href='https://wandb.ai/luchalt/V03_Dropout/runs/oexlrfcc' target="_blank">cosmic-sweep-5</a></strong> to <a href='https://wandb.ai/luchalt/V03_Dropout' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic' target="_blank">https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic</a>
#  View project at <a href='https://wandb.ai/luchalt/V03_Dropout' target="_blank">https://wandb.ai/luchalt/V03_Dropout</a>
#  View sweep at <a href='https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic' target="_blank">https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic</a>
#  View run at <a href='https://wandb.ai/luchalt/V03_Dropout/runs/oexlrfcc' target="_blank">https://wandb.ai/luchalt/V03_Dropout/runs/oexlrfcc</a>
# Epoch 1/20
# 2023-11-06 15:39:17.740436: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 1875/1875 [==============================] - 11s 4ms/step - loss: 8.4629 - accuracy: 0.3554 - val_loss: 6.4031 - val_accuracy: 0.8194
# Epoch 2/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 5.9781 - accuracy: 0.6755 - val_loss: 4.6710 - val_accuracy: 0.8967
# Epoch 3/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 4.3319 - accuracy: 0.7964 - val_loss: 3.3798 - val_accuracy: 0.9297
# Epoch 4/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 3.1191 - accuracy: 0.8579 - val_loss: 2.4223 - val_accuracy: 0.9442
# Epoch 5/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 2.2505 - accuracy: 0.8907 - val_loss: 1.7424 - val_accuracy: 0.9540
# Epoch 6/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 1.6425 - accuracy: 0.9118 - val_loss: 1.2682 - val_accuracy: 0.9608
# Epoch 7/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 1.2229 - accuracy: 0.9256 - val_loss: 0.9402 - val_accuracy: 0.9655
# Epoch 8/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.9304 - accuracy: 0.9363 - val_loss: 0.7121 - val_accuracy: 0.9692
# Epoch 9/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.7280 - accuracy: 0.9416 - val_loss: 0.5521 - val_accuracy: 0.9715
# Epoch 10/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5844 - accuracy: 0.9482 - val_loss: 0.4392 - val_accuracy: 0.9740
# Epoch 11/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4795 - accuracy: 0.9533 - val_loss: 0.3551 - val_accuracy: 0.9767
# Epoch 12/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4024 - accuracy: 0.9558 - val_loss: 0.2942 - val_accuracy: 0.9790
# Epoch 13/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3433 - accuracy: 0.9590 - val_loss: 0.2474 - val_accuracy: 0.9804
# Epoch 14/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2993 - accuracy: 0.9618 - val_loss: 0.2123 - val_accuracy: 0.9821
# Epoch 15/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2645 - accuracy: 0.9636 - val_loss: 0.1839 - val_accuracy: 0.9828
# Epoch 16/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2352 - accuracy: 0.9653 - val_loss: 0.1615 - val_accuracy: 0.9849
# Epoch 17/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2144 - accuracy: 0.9664 - val_loss: 0.1447 - val_accuracy: 0.9845
# Epoch 18/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1963 - accuracy: 0.9686 - val_loss: 0.1307 - val_accuracy: 0.9860
# Epoch 19/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1811 - accuracy: 0.9694 - val_loss: 0.1186 - val_accuracy: 0.9860
# Epoch 20/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1676 - accuracy: 0.9710 - val_loss: 0.1079 - val_accuracy: 0.9863
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▅▆▇▇▇▇█████████████</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▆▅▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▆▆▇▇▇▇▇▇██████████</td></tr><tr><td>val_loss</td><td>█▆▅▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.97103</td></tr><tr><td>best_epoch</td><td>19</td></tr><tr><td>best_val_loss</td><td>0.10791</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>loss</td><td>0.16761</td></tr><tr><td>val_accuracy</td><td>0.9863</td></tr><tr><td>val_loss</td><td>0.10791</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">cosmic-sweep-5</strong> at: <a href='https://wandb.ai/luchalt/V03_Dropout/runs/oexlrfcc' target="_blank">https://wandb.ai/luchalt/V03_Dropout/runs/oexlrfcc</a><br/>Synced 6 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231106_153821-oexlrfcc/logs</code>
# wandb: Agent Starting Run: q3cnn3j9 with config:
# wandb: 	activation1: ['relu']
# wandb: 	activation2: ['relu']
# wandb: 	activation3: ['sigmoid']
# wandb: 	batch_size: 32
# wandb: 	do1: 0.51
# wandb: 	do2: 0.51
# wandb: 	do3: 0.6100000000000001
# wandb: 	do4: 0.56
# wandb: 	epochs: 20
# wandb: 	gn1: 0.76
# wandb: 	learning_rate: 1e-05
# wandb: 	neurons1: 26
# wandb: 	neurons2: 26
# wandb: 	neurons3: 54
# wandb: 	optimizer: adam
# wandb version 0.15.12 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20231106_154214-q3cnn3j9</code>
# Syncing run <strong><a href='https://wandb.ai/luchalt/V03_Dropout/runs/q3cnn3j9' target="_blank">divine-sweep-6</a></strong> to <a href='https://wandb.ai/luchalt/V03_Dropout' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic' target="_blank">https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic</a>
#  View project at <a href='https://wandb.ai/luchalt/V03_Dropout' target="_blank">https://wandb.ai/luchalt/V03_Dropout</a>
#  View sweep at <a href='https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic' target="_blank">https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic</a>
#  View run at <a href='https://wandb.ai/luchalt/V03_Dropout/runs/q3cnn3j9' target="_blank">https://wandb.ai/luchalt/V03_Dropout/runs/q3cnn3j9</a>
# Epoch 1/20
# 2023-11-06 15:43:10.652685: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 1875/1875 [==============================] - 11s 5ms/step - loss: 8.4578 - accuracy: 0.3442 - val_loss: 6.3951 - val_accuracy: 0.8205
# Epoch 2/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 5.9403 - accuracy: 0.6730 - val_loss: 4.6461 - val_accuracy: 0.9013
# Epoch 3/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 4.2813 - accuracy: 0.7958 - val_loss: 3.3311 - val_accuracy: 0.9305
# Epoch 4/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 3.0600 - accuracy: 0.8559 - val_loss: 2.3598 - val_accuracy: 0.9464
# Epoch 5/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 2.1853 - accuracy: 0.8901 - val_loss: 1.6754 - val_accuracy: 0.9569
# Epoch 6/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 1.5845 - accuracy: 0.9105 - val_loss: 1.2077 - val_accuracy: 0.9621
# Epoch 7/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 1.1708 - accuracy: 0.9257 - val_loss: 0.8891 - val_accuracy: 0.9659
# Epoch 8/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.8938 - accuracy: 0.9336 - val_loss: 0.6721 - val_accuracy: 0.9710
# Epoch 9/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.6953 - accuracy: 0.9426 - val_loss: 0.5191 - val_accuracy: 0.9734
# Epoch 10/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5580 - accuracy: 0.9481 - val_loss: 0.4107 - val_accuracy: 0.9765
# Epoch 11/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4560 - accuracy: 0.9525 - val_loss: 0.3322 - val_accuracy: 0.9788
# Epoch 12/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3826 - accuracy: 0.9565 - val_loss: 0.2748 - val_accuracy: 0.9804
# Epoch 13/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3275 - accuracy: 0.9598 - val_loss: 0.2315 - val_accuracy: 0.9817
# Epoch 14/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2829 - accuracy: 0.9627 - val_loss: 0.1980 - val_accuracy: 0.9826
# Epoch 15/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2516 - accuracy: 0.9646 - val_loss: 0.1713 - val_accuracy: 0.9839
# Epoch 16/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2255 - accuracy: 0.9657 - val_loss: 0.1506 - val_accuracy: 0.9853
# Epoch 17/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2027 - accuracy: 0.9681 - val_loss: 0.1333 - val_accuracy: 0.9858
# Epoch 18/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1861 - accuracy: 0.9693 - val_loss: 0.1206 - val_accuracy: 0.9862
# Epoch 19/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1723 - accuracy: 0.9705 - val_loss: 0.1095 - val_accuracy: 0.9873
# Epoch 20/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1599 - accuracy: 0.9709 - val_loss: 0.1008 - val_accuracy: 0.9875
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.004 MB of 0.004 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▅▆▇▇▇▇█████████████</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▆▄▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▆▆▇▇▇▇▇███████████</td></tr><tr><td>val_loss</td><td>█▆▅▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.97092</td></tr><tr><td>best_epoch</td><td>19</td></tr><tr><td>best_val_loss</td><td>0.10083</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>loss</td><td>0.15992</td></tr><tr><td>val_accuracy</td><td>0.9875</td></tr><tr><td>val_loss</td><td>0.10083</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">divine-sweep-6</strong> at: <a href='https://wandb.ai/luchalt/V03_Dropout/runs/q3cnn3j9' target="_blank">https://wandb.ai/luchalt/V03_Dropout/runs/q3cnn3j9</a><br/>Synced 6 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231106_154214-q3cnn3j9/logs</code>
# wandb: Agent Starting Run: wy6b04ly with config:
# wandb: 	activation1: ['relu']
# wandb: 	activation2: ['relu']
# wandb: 	activation3: ['sigmoid']
# wandb: 	batch_size: 32
# wandb: 	do1: 0.51
# wandb: 	do2: 0.6100000000000001
# wandb: 	do3: 0.56
# wandb: 	do4: 0.46
# wandb: 	epochs: 20
# wandb: 	gn1: 0.76
# wandb: 	learning_rate: 1e-05
# wandb: 	neurons1: 26
# wandb: 	neurons2: 26
# wandb: 	neurons3: 54
# wandb: 	optimizer: adam
# wandb version 0.15.12 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20231106_154608-wy6b04ly</code>
# Syncing run <strong><a href='https://wandb.ai/luchalt/V03_Dropout/runs/wy6b04ly' target="_blank">clear-sweep-7</a></strong> to <a href='https://wandb.ai/luchalt/V03_Dropout' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic' target="_blank">https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic</a>
#  View project at <a href='https://wandb.ai/luchalt/V03_Dropout' target="_blank">https://wandb.ai/luchalt/V03_Dropout</a>
#  View sweep at <a href='https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic' target="_blank">https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic</a>
#  View run at <a href='https://wandb.ai/luchalt/V03_Dropout/runs/wy6b04ly' target="_blank">https://wandb.ai/luchalt/V03_Dropout/runs/wy6b04ly</a>
# Epoch 1/20
# 2023-11-06 15:47:05.312494: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 1875/1875 [==============================] - 11s 5ms/step - loss: 8.3356 - accuracy: 0.3868 - val_loss: 6.3735 - val_accuracy: 0.8239
# Epoch 2/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 5.9471 - accuracy: 0.6824 - val_loss: 4.6557 - val_accuracy: 0.9028
# Epoch 3/20
# 1875/1875 [==============================] - 8s 5ms/step - loss: 4.3017 - accuracy: 0.7993 - val_loss: 3.3523 - val_accuracy: 0.9318
# Epoch 4/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 3.0871 - accuracy: 0.8568 - val_loss: 2.3862 - val_accuracy: 0.9444
# Epoch 5/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 2.2118 - accuracy: 0.8900 - val_loss: 1.6993 - val_accuracy: 0.9526
# Epoch 6/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 1.6052 - accuracy: 0.9094 - val_loss: 1.2311 - val_accuracy: 0.9576
# Epoch 7/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 1.1903 - accuracy: 0.9228 - val_loss: 0.9081 - val_accuracy: 0.9625
# Epoch 8/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.9066 - accuracy: 0.9322 - val_loss: 0.6874 - val_accuracy: 0.9667
# Epoch 9/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.7085 - accuracy: 0.9407 - val_loss: 0.5323 - val_accuracy: 0.9704
# Epoch 10/20
# ...
# Find logs at: <code>./wandb/run-20231106_164259-re3n0pdx/logs</code>
# wandb: Agent Starting Run: p3g85z6x with config:
# wandb: 	activation1: ['relu']
# wandb: 	activation2: ['relu']
# wandb: 	activation3: ['sigmoid']
# wandb: 	batch_size: 32
# wandb: 	do1: 0.7100000000000001
# wandb: 	do2: 0.6100000000000001
# wandb: 	do3: 0.51
# wandb: 	do4: 0.16000000000000003
# wandb: 	epochs: 20
# wandb: 	gn1: 0.26
# wandb: 	learning_rate: 1e-05
# wandb: 	neurons1: 26
# wandb: 	neurons2: 26
# wandb: 	neurons3: 54
# wandb: 	optimizer: adam
# wandb version 0.15.12 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20231106_164727-p3g85z6x</code>
# Syncing run <strong><a href='https://wandb.ai/luchalt/V03_Dropout/runs/p3g85z6x' target="_blank">ruby-sweep-22</a></strong> to <a href='https://wandb.ai/luchalt/V03_Dropout' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic' target="_blank">https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic</a>
#  View project at <a href='https://wandb.ai/luchalt/V03_Dropout' target="_blank">https://wandb.ai/luchalt/V03_Dropout</a>
#  View sweep at <a href='https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic' target="_blank">https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic</a>
#  View run at <a href='https://wandb.ai/luchalt/V03_Dropout/runs/p3g85z6x' target="_blank">https://wandb.ai/luchalt/V03_Dropout/runs/p3g85z6x</a>
# Epoch 1/20
# 2023-11-06 16:48:23.466909: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 1875/1875 [==============================] - 11s 4ms/step - loss: 8.3575 - accuracy: 0.3751 - val_loss: 6.2885 - val_accuracy: 0.8477
# Epoch 2/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 5.9023 - accuracy: 0.6804 - val_loss: 4.6071 - val_accuracy: 0.9023
# Epoch 3/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 4.2908 - accuracy: 0.7929 - val_loss: 3.3407 - val_accuracy: 0.9278
# Epoch 4/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 3.1044 - accuracy: 0.8500 - val_loss: 2.4017 - val_accuracy: 0.9418
# Epoch 5/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 2.2410 - accuracy: 0.8873 - val_loss: 1.7325 - val_accuracy: 0.9518
# Epoch 6/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 1.6466 - accuracy: 0.9068 - val_loss: 1.2667 - val_accuracy: 0.9582
# Epoch 7/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 1.2320 - accuracy: 0.9200 - val_loss: 0.9422 - val_accuracy: 0.9633
# Epoch 8/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.9412 - accuracy: 0.9317 - val_loss: 0.7157 - val_accuracy: 0.9676
# Epoch 9/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.7362 - accuracy: 0.9404 - val_loss: 0.5555 - val_accuracy: 0.9704
# Epoch 10/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5897 - accuracy: 0.9455 - val_loss: 0.4409 - val_accuracy: 0.9737
# Epoch 11/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4851 - accuracy: 0.9509 - val_loss: 0.3566 - val_accuracy: 0.9766
# Epoch 12/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4045 - accuracy: 0.9555 - val_loss: 0.2951 - val_accuracy: 0.9782
# Epoch 13/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3449 - accuracy: 0.9580 - val_loss: 0.2464 - val_accuracy: 0.9804
# Epoch 14/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3020 - accuracy: 0.9596 - val_loss: 0.2127 - val_accuracy: 0.9821
# Epoch 15/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2661 - accuracy: 0.9623 - val_loss: 0.1845 - val_accuracy: 0.9826
# Epoch 16/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2379 - accuracy: 0.9653 - val_loss: 0.1621 - val_accuracy: 0.9830
# Epoch 17/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2166 - accuracy: 0.9662 - val_loss: 0.1448 - val_accuracy: 0.9837
# Epoch 18/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1974 - accuracy: 0.9671 - val_loss: 0.1305 - val_accuracy: 0.9845
# Epoch 19/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1805 - accuracy: 0.9696 - val_loss: 0.1189 - val_accuracy: 0.9851
# Epoch 20/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1686 - accuracy: 0.9700 - val_loss: 0.1089 - val_accuracy: 0.9850
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▅▆▇▇▇▇█████████████</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▆▅▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▅▆▆▇▇▇▇▇██████████</td></tr><tr><td>val_loss</td><td>█▆▅▄▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.97002</td></tr><tr><td>best_epoch</td><td>19</td></tr><tr><td>best_val_loss</td><td>0.10888</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>loss</td><td>0.16856</td></tr><tr><td>val_accuracy</td><td>0.985</td></tr><tr><td>val_loss</td><td>0.10888</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ruby-sweep-22</strong> at: <a href='https://wandb.ai/luchalt/V03_Dropout/runs/p3g85z6x' target="_blank">https://wandb.ai/luchalt/V03_Dropout/runs/p3g85z6x</a><br/>Synced 6 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231106_164727-p3g85z6x/logs</code>
# wandb: Agent Starting Run: mjvoee56 with config:
# wandb: 	activation1: ['relu']
# wandb: 	activation2: ['relu']
# wandb: 	activation3: ['sigmoid']
# wandb: 	batch_size: 32
# wandb: 	do1: 0.66
# wandb: 	do2: 0.41
# wandb: 	do3: 0.26
# wandb: 	do4: 0.7100000000000001
# wandb: 	epochs: 20
# wandb: 	gn1: 0.16000000000000003
# wandb: 	learning_rate: 1e-05
# wandb: 	neurons1: 26
# wandb: 	neurons2: 26
# wandb: 	neurons3: 54
# wandb: 	optimizer: adam
# wandb version 0.15.12 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20231106_165115-mjvoee56</code>
# Syncing run <strong><a href='https://wandb.ai/luchalt/V03_Dropout/runs/mjvoee56' target="_blank">deep-sweep-23</a></strong> to <a href='https://wandb.ai/luchalt/V03_Dropout' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic' target="_blank">https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic</a>
#  View project at <a href='https://wandb.ai/luchalt/V03_Dropout' target="_blank">https://wandb.ai/luchalt/V03_Dropout</a>
#  View sweep at <a href='https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic' target="_blank">https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic</a>
#  View run at <a href='https://wandb.ai/luchalt/V03_Dropout/runs/mjvoee56' target="_blank">https://wandb.ai/luchalt/V03_Dropout/runs/mjvoee56</a>
# Epoch 1/20
# 2023-11-06 16:52:11.892445: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 1875/1875 [==============================] - 11s 5ms/step - loss: 8.2809 - accuracy: 0.4106 - val_loss: 6.2696 - val_accuracy: 0.8639
# Epoch 2/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 5.8632 - accuracy: 0.7177 - val_loss: 4.6007 - val_accuracy: 0.9210
# Epoch 3/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 4.2394 - accuracy: 0.8263 - val_loss: 3.3129 - val_accuracy: 0.9413
# Epoch 4/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 3.0289 - accuracy: 0.8754 - val_loss: 2.3464 - val_accuracy: 0.9543
# Epoch 5/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 2.1623 - accuracy: 0.9023 - val_loss: 1.6633 - val_accuracy: 0.9600
# Epoch 6/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 1.5575 - accuracy: 0.9207 - val_loss: 1.1980 - val_accuracy: 0.9650
# Epoch 7/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 1.1525 - accuracy: 0.9316 - val_loss: 0.8824 - val_accuracy: 0.9696
# Epoch 8/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.8783 - accuracy: 0.9383 - val_loss: 0.6670 - val_accuracy: 0.9718
# Epoch 9/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.6850 - accuracy: 0.9452 - val_loss: 0.5165 - val_accuracy: 0.9749
# Epoch 10/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5485 - accuracy: 0.9516 - val_loss: 0.4090 - val_accuracy: 0.9773
# Epoch 11/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4513 - accuracy: 0.9554 - val_loss: 0.3309 - val_accuracy: 0.9789
# Epoch 12/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3790 - accuracy: 0.9586 - val_loss: 0.2728 - val_accuracy: 0.9801
# Epoch 13/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3227 - accuracy: 0.9609 - val_loss: 0.2305 - val_accuracy: 0.9819
# Epoch 14/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2820 - accuracy: 0.9631 - val_loss: 0.1970 - val_accuracy: 0.9836
# Epoch 15/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2486 - accuracy: 0.9651 - val_loss: 0.1707 - val_accuracy: 0.9850
# Epoch 16/20
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.2236 - accuracy: 0.9668 - val_loss: 0.1512 - val_accuracy: 0.9842
# Epoch 17/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2011 - accuracy: 0.9689 - val_loss: 0.1335 - val_accuracy: 0.9855
# Epoch 18/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1848 - accuracy: 0.9697 - val_loss: 0.1206 - val_accuracy: 0.9852
# Epoch 19/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1707 - accuracy: 0.9703 - val_loss: 0.1099 - val_accuracy: 0.9861
# Epoch 20/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1576 - accuracy: 0.9720 - val_loss: 0.1009 - val_accuracy: 0.9864
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▅▆▇▇▇▇█████████████</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▆▅▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▅▆▆▇▇▇▇▇██████████</td></tr><tr><td>val_loss</td><td>█▆▅▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.97198</td></tr><tr><td>best_epoch</td><td>19</td></tr><tr><td>best_val_loss</td><td>0.10094</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>loss</td><td>0.15763</td></tr><tr><td>val_accuracy</td><td>0.9864</td></tr><tr><td>val_loss</td><td>0.10094</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">deep-sweep-23</strong> at: <a href='https://wandb.ai/luchalt/V03_Dropout/runs/mjvoee56' target="_blank">https://wandb.ai/luchalt/V03_Dropout/runs/mjvoee56</a><br/>Synced 6 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231106_165115-mjvoee56/logs</code>
# wandb: Agent Starting Run: u3gb25yl with config:
# wandb: 	activation1: ['relu']
# wandb: 	activation2: ['relu']
# wandb: 	activation3: ['sigmoid']
# wandb: 	batch_size: 32
# wandb: 	do1: 0.7100000000000001
# wandb: 	do2: 0.6100000000000001
# wandb: 	do3: 0.060000000000000005
# wandb: 	do4: 0.56
# wandb: 	epochs: 20
# wandb: 	gn1: 0.36000000000000004
# wandb: 	learning_rate: 1e-05
# wandb: 	neurons1: 26
# wandb: 	neurons2: 26
# wandb: 	neurons3: 54
# wandb: 	optimizer: adam
# wandb version 0.15.12 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20231106_165545-u3gb25yl</code>
# Syncing run <strong><a href='https://wandb.ai/luchalt/V03_Dropout/runs/u3gb25yl' target="_blank">spring-sweep-24</a></strong> to <a href='https://wandb.ai/luchalt/V03_Dropout' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic' target="_blank">https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic</a>
#  View project at <a href='https://wandb.ai/luchalt/V03_Dropout' target="_blank">https://wandb.ai/luchalt/V03_Dropout</a>
#  View sweep at <a href='https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic' target="_blank">https://wandb.ai/luchalt/V03_Dropout/sweeps/vq8376ic</a>
#  View run at <a href='https://wandb.ai/luchalt/V03_Dropout/runs/u3gb25yl' target="_blank">https://wandb.ai/luchalt/V03_Dropout/runs/u3gb25yl</a>
# Epoch 1/20
# 2023-11-06 16:56:40.911801: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 1875/1875 [==============================] - 11s 4ms/step - loss: 8.4056 - accuracy: 0.3620 - val_loss: 6.3609 - val_accuracy: 0.8036
# Epoch 2/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 5.9480 - accuracy: 0.6610 - val_loss: 4.6408 - val_accuracy: 0.8893
# Epoch 3/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 4.3116 - accuracy: 0.7817 - val_loss: 3.3480 - val_accuracy: 0.9237
# Epoch 4/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 3.1077 - accuracy: 0.8437 - val_loss: 2.3934 - val_accuracy: 0.9426
# Epoch 5/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 2.2358 - accuracy: 0.8814 - val_loss: 1.7104 - val_accuracy: 0.9527
# Epoch 6/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 1.6196 - accuracy: 0.9068 - val_loss: 1.2344 - val_accuracy: 0.9608
# Epoch 7/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 1.1982 - accuracy: 0.9222 - val_loss: 0.9075 - val_accuracy: 0.9662
# Epoch 8/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.9070 - accuracy: 0.9335 - val_loss: 0.6802 - val_accuracy: 0.9710
# Epoch 9/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.7026 - accuracy: 0.9415 - val_loss: 0.5239 - val_accuracy: 0.9738
# Epoch 10/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5593 - accuracy: 0.9478 - val_loss: 0.4134 - val_accuracy: 0.9752
# Epoch 11/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4589 - accuracy: 0.9524 - val_loss: 0.3321 - val_accuracy: 0.9792
# Epoch 12/20
#  623/1875 [========>.....................] - ETA: 5s - loss: 0.4078 - accuracy: 0.9540

# %%
# after the training finishes, we will also save Marvin in Keras style (HDF5), so we do not have to
# train him again
# every time we start our computer. Obviously, by changing the model_name, you can also save different
# configurations of Marvin. The name has to be a string, like this: 'name.h5'
model_name = 'pepsi_p62k_a9915'
model.save(model_name, save_format='h5')

# It is best practice to indicate what configuration changes you did within the name, so you know
# which model you need to load already from its name
# Let's say instead of a learning rate of 0.001 you used 0.1, your naming could then look like:
# 'marvin_lr01.h5'

print('Success! You saved Marvin as: ', model_name)

# %%
# load a saved marvin configuration you want to evaluate
model_name = 'pepsi_lr03'
pepsi_reloaded = tf.keras.models.load_model(model_name)

# Let Marvin predict on the test set, so we have some data to evaluate his performance.
predictions = pepsi_reloaded.predict([x_test])
# predictions = pepsi.predict([x_test])

# Remember that the prediction of Marvin is a probability distribution over all ten-digit classes
# We want him to assign the digit class with the highest probability to the sample.
predictions = np.argmax(predictions, axis=1)
#pd.DataFrame(predictions)

# Plot for the intuitive approach

numbers_to_display = 196
num_cells = math.ceil(math.sqrt(numbers_to_display))
plt.figure(figsize=(15, 15))

for plot_index in range(numbers_to_display):
    predicted_label = predictions[plot_index]
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    color_map = 'Greens' if predicted_label == y_test[plot_index] else 'Reds'
    plt.subplot(num_cells, num_cells, plot_index + 1)
    plt.imshow(x_test_normalized[plot_index].reshape((28, 28)), cmap=color_map)
    plt.xlabel(predicted_label)

plt.subplots_adjust(hspace=1, wspace=0.5)
plt.show()

# %%
confusion_matrix = tf.math.confusion_matrix(y_test, predictions)

f, ax = plt.subplots(figsize=(9, 7))
sn.heatmap(
    confusion_matrix,
    annot=True,
    linewidths=.7,
    fmt="d",
    square=True,
    ax=ax,
    cmap="viridis",
)
plt.show()
